# %%
# Logistic Regression/ Binary classification

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   28                 0
# 1   36                 0
# 2   20                 0
# 3   12                 0
# 4   18                 0

# %%
plt.scatter(df.age, df.bought_insurance)

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size = 0.9)

# %%
x_test
# Out:
#     age
# 14   47
# 5    36
# 2    20

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 0], dtype=int64)

# %%
x_test
# Out:
#     age
# 14   47
# 5    36
# 2    20

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)  # probability
# Out:
# array([[4.19331989e-01, 5.80668011e-01],
#        [9.64051800e-01, 3.59482002e-02],
#        [9.99805841e-01, 1.94158762e-04]])

# %%
model.predict([[55]])
# Out:
# E:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
