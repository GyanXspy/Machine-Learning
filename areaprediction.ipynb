# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
from sklearn import linear_model

# %%
df = pd.read_csv('area.csv')
df
# Out:
#    Area  Price
# 0  4500  50000
# 1  1200  12000
# 2  4000  45100
# 3  1245  12555
# 4  1455  13555

# %%
pl.xlabel('Area')
pl.ylabel('Price')
pl.scatter(df.Area, df.Price, color = 'red')
pl.plot(df.Area, reg.predict(df[['Area']]), color = 'blue')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 pl.ylabel('Price')
#       3 pl.scatter(df.Area, df.Price, color = 'red')
# ----> 4 pl.plot(df.Area, reg.predict(df[['Area']]), color = 'blue')
#
# File E:\Anaconda\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File E:\Anaconda\Lib\site-packages\sklearn\linear_model\_base.py:267, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
# --> 267     check_is_fitted(self)
#     269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# E:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36291.17789166])

# %%
reg.coef_
# Out:
# array([11.76729011])

# %%
reg. intercept_
# Out:
# -2540.879477230188

# %%
price = 11.76729011*3300+ -2540.879477230188
price
# Out:
# 36291.17788576981

# %%
d = pd.read_csv('onlyarea.csv')
d.head()
# Out:
#     Area
# 0   4500
# 1  15778
# 2  23656
# 3   6852
# 4  23658

# %%
p = reg.predict(d)

# %%
d['price'] = p

# %%
d.to_csv('onlyarea.csv')

# %%
p
# Out:
# array([  50411.92602581,  183123.42390654,  275826.13540719,
#          78088.59236873,  275849.66998741, 2090801.19495901,
#          25018.11396457])
